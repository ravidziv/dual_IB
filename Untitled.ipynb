# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'mlruns/0/5a785185e3f9478e8ce1b0abadc2b287/artifacts/c_looger.csv'

# %%
df = pd.read_csv(path)

# %%
plt.plot(df['step'], df['val_acc'])
plt.plot(df['step'], df['loss'])
#plt.hlines(xmin = 0, xmax = 60, y = 0.014250342)
#plt.xscale('log')
#plt.yscale('log')

# %%
 df['val_loss']
# Out:
# 0    0.058916
# Name: val_loss, dtype: float64
